# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("E:/NLP/Reviews.csv")
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
df.columns
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %%
df["Helpfulness %"] = np.where(df["HelpfulnessDenominator"]>0,df["HelpfulnessNumerator"]/df["HelpfulnessDenominator"],-1)

# %%
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text  \
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
df["Helpfulness %"].unique()
# Out:
# array([ 1.        , -1.        ,  0.8       ,  0.        ,  0.5       ,
#         0.66666667,  0.25      ,  0.89473684,  0.83333333,  0.75      ,
#         0.33333333,  0.3       ,  0.11111111,  0.42857143,  0.875     ,
#         0.85714286,  0.2       ,  0.26315789,  0.6       ,  0.71428571,
#         0.53846154,  0.57142857,  0.91489362,  0.86666667,  0.82352941,
#         0.78571429,  0.74074074,  0.4       ,  0.375     ,  0.28571429,
#         0.14285714,  0.77777778,  0.125     ,  0.9       ,  0.94117647,
#         0.92307692,  0.7       ,  0.45454545,  0.88888889,  0.83870968,
#         0.9047619 ,  0.92857143,  0.90909091,  0.91666667,  0.84615385,
#         0.10526316,  0.98214286,  0.97826087,  0.7518797 ,  0.3125    ,
#         0.1       ,  0.18518519,  0.88      ,  0.69230769,  0.625     ,
#         0.54545455,  0.41666667,  0.45833333,  0.22222222,  0.81818182,
#         0.8125    ,  0.16666667,  0.93103448,  0.88235294,  0.23529412,
# ...

# %%
df["upvote%"]=pd.cut(df["Helpfulness %"],bins=[-1,0,0.2,0.4,0.6,0.8,1],labels=["Empty","0-20%","20-40%","40-60%","60-80%","80-100%"])

# %%
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text  \
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
df.groupby(["Score","upvote%"]).agg("count")
# Out:
#                    Id  ProductId  UserId  ProfileName  HelpfulnessNumerator  \
# Score upvote%
# 1     Empty      8060       8060    8060         8060                  8060
#       0-20%      2338       2338    2338         2338                  2338
#       20-40%     4649       4649    4649         4649                  4649
#       40-60%     6586       6586    6586         6586                  6586
#       60-80%     5838       5838    5838         5836                  5838
#       80-100%   12531      12531   12531        12531                 12531
# 2     Empty      4234       4234    4234         4234                  4234
#       0-20%       762        762     762          762                   762
#       20-40%     1618       1618    1618         1618                  1618
#       40-60%     3051       3051    3051         3051                  3051
#       60-80%     2486       2486    2486         2486                  2486
# ...

# %%
df_s = df.groupby(["Score","upvote%"]).agg({"Id":"count"}).reset_index()

# %%
df_s
# Out:
#     Score  upvote%      Id
# 0       1    Empty    8060
# 1       1    0-20%    2338
# 2       1   20-40%    4649
# 3       1   40-60%    6586
# 4       1   60-80%    5838
# 5       1  80-100%   12531
# 6       2    Empty    4234
# 7       2    0-20%     762
# 8       2   20-40%    1618
# 9       2   40-60%    3051
# 10      2   60-80%    2486
# 11      2  80-100%    7014
# 12      3    Empty    5062
# 13      3    0-20%     474
# 14      3   20-40%    1506
# 15      3   40-60%    3384
# 16      3   60-80%    2754
# 17      3  80-100%   11037
# 18      4    Empty    4780
# 19      4    0-20%     116
# 20      4   20-40%     909
# 21      4   40-60%    3185
# 22      4   60-80%    2941
# 23      4  80-100%   26707
# 24      5    Empty   11638
# 25      5    0-20%     432
# 26      5   20-40%    2275
# 27      5   40-60%   10312
# 28      5   60-80%   11060
# 29      5  80-100%  140661

# %%
pt=df_s.pivot(index="upvote%", columns="Score")
pt
# Out:
#             Id
# Score        1     2      3      4       5
# upvote%
# Empty     8060  4234   5062   4780   11638
# 0-20%     2338   762    474    116     432
# 20-40%    4649  1618   1506    909    2275
# 40-60%    6586  3051   3384   3185   10312
# 60-80%    5838  2486   2754   2941   11060
# 80-100%  12531  7014  11037  26707  140661

# %%
 import seaborn as sns

# %%
sns.heatmap(pt,annot=True,cmap="YlGnBu")
# Out:
# <AxesSubplot:xlabel='None-Score', ylabel='upvote%'>

# %%
pt
# Out:
#             Id
# Score        1     2      3      4       5
# upvote%
# Empty     8060  4234   5062   4780   11638
# 0-20%     2338   762    474    116     432
# 20-40%    4649  1618   1506    909    2275
# 40-60%    6586  3051   3384   3185   10312
# 60-80%    5838  2486   2754   2941   11060
# 80-100%  12531  7014  11037  26707  140661

# %%
df["Score"].unique()
# Out:
# array([5, 1, 4, 2, 3], dtype=int64)

# %%
df2= df[df["Score"]!=3]

# %%
x = df2["Text"]

# %%
y_dict = {1:0,2:0,4:1,5:1}

# %%
y= df2["Score"].map(y_dict)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
c=CountVectorizer(stop_words="english")

# %%
x_c= c.fit_transform(x)

# %%
x_c.shape
# Out:
# (525814, 114969)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x_c,y)

# %%
x_train.shape
# Out:
# (394360, 114969)

# %%
from sklearn.linear_model import LogisticRegression

# %%
log=LogisticRegression()

# %%
m1=log.fit(x_train,y_train)
# Out:
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
m1.score(x_test,y_test)
# Out:
# 0.9361677849285681

# %%
w=c.get_feature_names()
w
# Out:
# ['00',
#  '000',
#  '0000',
#  '000001',
#  '00001',
#  '000013',
#  '0000soo',
#  '0001',
#  '000111052',
#  '0002251337',
#  '0003',
#  '0004',
#  '000iu',
#  '000kwh',
#  '000mg',
#  '000mi',
#  '000s',
#  '000su',
#  '000usd',
#  '000v',
#  '001',
#  '00100',
#  '00127',
#  '00128',
#  '00129',
#  '00130',
#  '00131',
#  '00132',
#  '00134',
#  '00136',
#  '00139',
#  '001bru',
#  '002',
#  '0020100604',
#  '00202',
#  '00227',
#  '0023',
#  '003',
#  '004',
#  '00493',
#  '005',
#  '00533',
#  '0060187654',
#  '0060721855',
#  '0060928115',
#  '0060959584',
#  '0061658197',
#  '006176793x',
#  '0067575986',
#  '0069615',
#  '007',
#  '00703',
#  '00704',
#  '0071468633',
#  '0071477845',
#  '0071486011',
#  '0071499849',
#  '008',
#  '0099',
#  '00a',
#  '00am',
#  '00b',
#  '00gr',
#  '00lb',
#  '00m',
#  '00pm',
#  '00s',
#  '00something',
#  '00z',
#  '01',
#  '010',
#  '0100',
#  '01014',
#  '01069',
#  '011',
#  '012',
#  '013',
#  '01317',
#  '01318',
#  '014',
# ...

# %%
coef=m1.coef_.tolist()[0]
coef
# Out:
# [-0.2845086226125739,
#  0.026989960946067853,
#  0.4584497482318864,
#  -0.006611330669573224,
#  -0.010377769278282397,
#  -0.012703600029339884,
#  0.00033790825198968345,
#  -0.012484198095116453,
#  0.0,
#  0.0,
#  0.002054759757554497,
#  -0.010035443038059508,
#  0.0,
#  0.011151083366762758,
#  -0.3154218050632167,
#  0.0017301009413857253,
#  0.002851119874453309,
#  0.0028837007139778763,
#  0.0,
#  4.787321338134875e-05,
#  -0.031954129273435265,
#  0.020289283025052854,
#  0.03818336850629285,
#  0.03818336850629285,
#  0.03818336850629285,
#  0.03818336850629285,
#  0.03818336850629285,
#  0.03818336850629285,
#  0.03818336850629285,
#  0.03818336850629285,
#  0.03818336850629285,
#  -0.00035098070795315403,
#  0.052407662051160125,
#  0.00016332301906297355,
#  0.0,
#  -0.0005683140686294135,
#  0.00015422160385529773,
#  0.0024637867042617426,
#  0.07749670818361377,
#  0.0,
#  -0.1000168615761489,
#  0.012165536090371382,
#  6.49000053063211e-05,
# ...

# %%
coef_of=pd.DataFrame({"Word":w,"Coefficient":coef})
coef_of
# Out:
#           Word  Coefficient
# 0           00    -0.284509
# 1          000     0.026990
# 2         0000     0.458450
# 3       000001    -0.006611
# 4        00001    -0.010378
# ...        ...          ...
# 114964  çaykur     0.000856
# 114965   çelem     0.000000
# 114966    être     0.021740
# 114967     île     0.008677
# 114968      ît     0.000395
#
# [114969 rows x 2 columns]

# %%
coef_of=coef_of.sort_values(["Coefficient","Word"],ascending=False)

# %%
coef_of.head(20)
# Out:
#               Word  Coefficient
# 80600   pleasantly     3.912260
# 39072     downside     3.105113
# 94667    skeptical     3.053020
# 5865     addicting     2.909485
# 113138     worries     2.422499
# 39214     drawback     2.414198
# 55029       hooked     2.407566
# 40135      easiest     2.126261
# 35726       delish     2.124348
# 87174     relaxing     2.103059
# 10992      awesome     2.069586
# 102857    terrific     2.059414
# 53675     heavenly     2.043846
# 111911        whim     2.032111
# 24746         calm     2.029846
# 43222    excellent     2.021451
# 87967       resist     2.017853
# 96353     soothing     2.010670
# 105162     trainer     1.994385
# 40342   economical     1.988737

# %%
def text_fit(x,y,nlp_model,ml_model):
    x_c=nlp_model.fit_transform(x)
    print("features:{}".format(x_c.shape[1]))
    x_train,x_test,y_train,y_test=train_test_split(x_c,y)
    ml=ml_model.fit(x_train,y_train)
    acc=ml.score(x_test,y_test)
    print(acc)
    w=c.get_feature_names()
    coef=m1.coef_.tolist()[0]
    coef_of=pd.DataFrame({"Word":w,"Coefficient":coef})
    coef_of=coef_of.sort_values(["Coefficient","Word"],ascending=False)

    print('\n')
    print("top 20 positive ")
    print(coef_of.head(20))
    print('\n')
    print("top 20 negative")
    print(coef_of.tail(20))

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
c=CountVectorizer(stop_words='english')

# %%
from sklearn.linear_model import LogisticRegression

# %%
text_fit(x,y,c,LogisticRegression())
# Out:
# features:114969
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.9357265659470233
#
#
# top 20 positive
#               Word  Coefficient
# 80600   pleasantly     3.912260
# 39072     downside     3.105113
# 94667    skeptical     3.053020
# 5865     addicting     2.909485
# 113138     worries     2.422499
# 39214     drawback     2.414198
# 55029       hooked     2.407566
# 40135      easiest     2.126261
# 35726       delish     2.124348
# 87174     relaxing     2.103059
# ...

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
def predict(x,y,nlp_model,ml_model):
    x_c=nlp_model.fit_transform(x)
    x_train,x_test,y_train,y_test=train_test_split(x_c,y)
    ml=ml_model.fit(x_train,y_train)
    predictions=ml.predict(x_test)
    cm=confusion_matrix(predictions,y_test)
    print(cm)
    acc=accuracy_score(predictions,y_test)
    print(acc)

# %%
c=CountVectorizer()
lr=LogisticRegression()

# %%
predict(x,y,c,lr)
# Out:
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [[ 14989   2742]
#  [  5616 108107]]
# 0.9364188233146196
